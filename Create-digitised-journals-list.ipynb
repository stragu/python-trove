# %% [markdown]
# # Create a list of Trove's digitised journals
#
# Everyone know's about Trove's newspapers, but there is also a growing collection of digitised journals available in the journals zone. They're not easy to find, however, which is why I created the [Trove Titles](https://trove-titles.herokuapp.com/) web app.
#
# This notebook uses the Trove API to harvest metadata relating to digitised journals – or more accurately, journals that are freely available online in a digital form. This includes some born digital publications that are available to view in formats like PDF and MOBI, but excludes some digital journals that have access restrictions.
#
# The search strategy to find digitised (and digital) journals takes advantage of the fact that Trove's digitised resources (excluding the newspapers) all have an identifier that includes the string `nla.obj`. So we start by searching in the journals zone for records that include `nla.obj` and have the `format` 'Periodical'. By specifying 'Periodical' we exclude individual articles from digitised journals.
#
# Then it's just a matter of looping through all the results and checking to see if a record includes a `fulltext` link to a digital copy. If it does it gets saved.
#
# You can see the results in [this CSV file](digital-journals.csv). Obviously you could extract additional metadata from each record if you wanted to.
#
# The default fields are:
#
# * `fulltext_url` – the url of the landing page of the digital version of the journal
# * `title` – the title of the journal
# * `trove_id` – the 'nla.obj' part of the fulltext_url, a unique identifier for the digital journal
# * `trove_url` – url of the journal's metadata record in Trove
#
# I've used this list to harvest all the OCRd text from digitised journals.

# %%
# Let's import the libraries we need.
import requests
import pandas as pd
from bs4 import BeautifulSoup
import time
import json
import os
import re
from tqdm.auto import tqdm
from requests.adapters import HTTPAdapter
from requests.packages.urllib3.util.retry import Retry
from slugify import slugify
from IPython.display import display, FileLink

s = requests.Session()
retries = Retry(total=5, backoff_factor=1, status_forcelist=[ 502, 503, 504 ])
s.mount('https://', HTTPAdapter(max_retries=retries))
s.mount('http://', HTTPAdapter(max_retries=retries))

# %% [markdown]
# ## Add your Trove API key
#
# You can get a Trove API key by [following these instructions](https://help.nla.gov.au/trove/building-with-trove/api).

# %%
# Add your Trove API key between the quotes
api_key = 'MY KEY'

# %% [markdown]
# ## Define some functions to do the work

# %%
def get_total_results(params):
    '''
    Get the total number of results for a search.
    '''
    these_params = params.copy()
    these_params['n'] = 0
    response = s.get('https://api.trove.nla.gov.au/v2/result', params=these_params)
    data = response.json()
    return int(data['response']['zone'][0]['records']['total'])


def get_fulltext_url(links):
    '''
    Loop through the identifiers to find a link to the digital version of the journal.
    '''
    nla_digitised = False
    for link in links:
        if link['linktype'] == 'fulltext' and 'nla.obj' in link['value']:
            url = link['value']
            if link['linktext'] == 'National Library of Australia digitised item':
                nla_digitised = True
            return url, nla_digitised


def get_titles():
    '''
    Harvest metadata about digitised journals.
    With a little adaptation, this basic pattern could be used to harvest
    other types of works from Trove.
    '''
    url = 'http://api.trove.nla.gov.au/v2/result'
    titles = []
    params = {
        # We can 'NOT' the format facet in the query
        'q': '"nla.obj-" NOT format:"Government publication" NOT format:Article',
        'zone': 'article',
        'l-format': 'Periodical', # Journals only
        'include': 'links',
        'bulkHarvest': 'true', # Needed to maintain a consistent order across requests
        'key': api_key,
        'n': 100,
        'encoding': 'json'
    }
    start = '*'
    total = get_total_results(params)
    with tqdm(total=total) as pbar:
        while start:
            params['s'] = start
            response = s.get(url, params=params)
            data = response.json()
            # If there's a startNext value then we get it to request the next page of results
            try:
                start = data['response']['zone'][0]['records']['nextStart']
            except KeyError:
                start = None
            for work in data['response']['zone'][0]['records']['work']:
                # Check to see if there's a link to a digital version
                try:
                    fulltext_url, nla_digitised = get_fulltext_url(work['identifier'])
                except (KeyError, TypeError):
                    pass
                else:
                    if fulltext_url:
                        trove_id = re.search(r'(nla\.obj\-\d+)', fulltext_url).group(1)
                        # Get basic metadata
                        # You could add more work data here
                        # Check the Trove API docs for work record structure
                        title = {
                            'title': work['title'],
                            'fulltext_url': fulltext_url, 
                            'trove_url': work['troveUrl'],
                            'trove_id': trove_id,
                            'nla_digitised': nla_digitised
                        }
                        titles.append(title)
            time.sleep(0.2)
            pbar.update(100)
    return titles

# %% [markdown]
# ## Run the harvest

# %%
titles = get_titles()
# Out:
# HBox(children=(FloatProgress(value=0.0, max=5055.0), HTML(value='')))

# %% [markdown]
# ## Convert to a dataframe and save as a CSV file
#
# Let's convert the Python list to a Pandas DataFrame, have a peek inside, then save in CSV format.

# %%
df = pd.DataFrame(titles)
df.head()
# Out:
#                                                title  \
# 0                         The Silver stream songster
# 1                       Stonequarry journal (Online)
# 2                Philament (Sydney, N.S.W. : Online)
# 3                   Journal (Queensland Law Society)
# 4  The Order of service for the annual festival t...
#
#                                 fulltext_url  \
# 0       https://nla.gov.au/nla.obj-614066685
# 1       https://nla.gov.au/nla.obj-862209995
# 2       https://nla.gov.au/nla.obj-749489295
# 3  https://www.nla.gov.au/nla.obj-2735787548
# 4        http://nla.gov.au/nla.obj-657473276
#
#                                 trove_url            trove_id  nla_digitised
# 0  https://trove.nla.gov.au/work/10087062   nla.obj-614066685          False
# 1  https://trove.nla.gov.au/work/10106079   nla.obj-862209995          False
# 2  https://trove.nla.gov.au/work/10287808   nla.obj-749489295          False
# 3  https://trove.nla.gov.au/work/10321820  nla.obj-2735787548          False
# 4  https://trove.nla.gov.au/work/10388163   nla.obj-657473276           True

# %%
# How many journals are there?
df.shape
# Out:
# (3033, 5)

# %% [markdown]
# For some reason there are a number of duplicates in the list, where multiple Trove work records point to the same digitised journal. We an display the duplicates like this.

# %%
# SHow all the rows
pd.set_option('display.max_rows', None)
# Show dupes
df.loc[df.duplicated(subset=['trove_id'], keep=False)].sort_values(by=['trove_id', 'nla_digitised'])
# Out:
#                                                   title  \
# 1708                    Wings (Sydney, N.S.W. : Online)
# 2641                             Wings (Sydney, N.S.W.)
# 735   [Event programme] / Australian Festival of Cha...
# 2045  [Event programme] / Australian Festival of Cha...
# 690                             The Brisbane Bushwalker
# 2534  The Brisbane bushwalker : monthly magazine of ...
# 713                           The shadowland newsletter
# 2988  The Atlas of the solar system / Patrick Moore ...
# 2096            Photographic review of reviews (Online)
# 2741                     Photographic review of reviews
# 2062             The Australian woman's mirror (Online)
# 2752                      The Australian woman's mirror
# 391                                U3A Sunshine e-Voice
# 1218                      U3A Sunshine e-Voice (Online)
# 271   Newsletter (Genealogical Society of Queensland...
# 1222                             Bremer echoes (Online)
# 2064  The New South Wales Post Office directory (Onl...
# 1581          The New South Wales Post Office directory
# 2063                Everyones (Sydney, N.S.W. : Online)
# 2927                                          Everyones
# 2070                    Month (Sydney, N.S.W. : Online)
# 2904                             Month (Sydney, N.S.W.)
# 2066                      South-Asian register (Online)
# 2905                           The South-Asian register
# 2068                   Tegg's monthly magazine (Online)
# 883                             Tegg's monthly magazine
# 2061        Rugby League news (Sydney, N.S.W. : Online)
# 2948                 Rugby League news (Sydney, N.S.W.)
# 2071        Bookfellow (Sydney, N.S.W. : 1899 : Online)
# 904                  Bookfellow (Sydney, N.S.W. : 1899)
# 2073  Australian magazine (Sydney, N.S.W. : 1899 : O...
# 427         Australian magazine (Sydney, N.S.W. : 1899)
# 358                    Bulletin (Sydney, N.S.W. : 1880)
# 40                                         The bulletin
# 2065         Dun's gazette for New South Wales (Online)
# 434                   Dun's gazette for New South Wales
# 2095              Weldon's matrimonial gazette (Online)
# 604                        Weldon's matrimonial gazette
# 2086  New South Wales school magazine of literature ...
# 9     The New South Wales school magazine of literat...
# 2078  Australian magazine (Sydney, N.S.W. : 1838 : O...
# 380         Australian magazine (Sydney, N.S.W. : 1838)
# 2084           New South Wales magazine (1833 : Online)
# 429                     New South Wales magazine (1833)
# 2094                            Sydney coronal (Online)
# 36             The Sydney coronal / by Charles M'Donald
# 2077  Tegg's New South Wales pocket almanac and reme...
# 2907  Tegg's New South Wales pocket almanac and reme...
# 2076                  Liberty (Sydney, N.S.W. : Online)
# 2961                           Liberty (Sydney, N.S.W.)
# 2072               Sydney once a week magazine (Online)
# 122                     The Sydney once a week magazine
# 2069                             Literary news (Online)
# 425   The Literary news : a review and magazine of f...
# 2082              Australia and the bookfellow (Online)
# 1025                       Australia and the bookfellow
# 2081         Australia (Sydney, N.S.W. : 1907 : Online)
# 1026                  Australia (Sydney, N.S.W. : 1907)
# 2083        Bookfellow (Sydney, N.S.W. : 1911 : Online)
# 1027                 Bookfellow (Sydney, N.S.W. : 1911)
# 2085                                 New Triad (Online)
# 2931                                      The New Triad
# 2074                    Triad (Sydney, N.S.W. : Online)
# 2615                             Triad (Sydney, N.S.W.)
#
#                                fulltext_url  \
# 1708  https://nla.gov.au/nla.obj-1226109179
# 2641  https://nla.gov.au/nla.obj-1226109179
# 735   https://nla.gov.au/nla.obj-1252107366
# 2045  https://nla.gov.au/nla.obj-1252107366
# 690   https://nla.gov.au/nla.obj-1252263267
# 2534  https://nla.gov.au/nla.obj-1252263267
# 713   https://nla.gov.au/nla.obj-1771610885
# 2988  https://nla.gov.au/nla.obj-1771610885
# 2096    http://nla.gov.au/nla.obj-389050007
# 2741    http://nla.gov.au/nla.obj-389050007
# 2062    http://nla.gov.au/nla.obj-389050376
# 2752    http://nla.gov.au/nla.obj-389050376
# 391    https://nla.gov.au/nla.obj-483060448
# 1218   https://nla.gov.au/nla.obj-483060448
# 271    https://nla.gov.au/nla.obj-485357469
# 1222   https://nla.gov.au/nla.obj-485357469
# 2064    http://nla.gov.au/nla.obj-518308191
# 1581    http://nla.gov.au/nla.obj-518308191
# 2063    http://nla.gov.au/nla.obj-522690001
# 2927    http://nla.gov.au/nla.obj-522690001
# 2070    http://nla.gov.au/nla.obj-597762006
# 2904    http://nla.gov.au/nla.obj-597762006
# 2066    http://nla.gov.au/nla.obj-597769314
# 2905    http://nla.gov.au/nla.obj-597769314
# 2068    http://nla.gov.au/nla.obj-598267619
# 883     http://nla.gov.au/nla.obj-598267619
# 2061    http://nla.gov.au/nla.obj-598579045
# 2948    http://nla.gov.au/nla.obj-598579045
# 2071    http://nla.gov.au/nla.obj-636005630
# 904     http://nla.gov.au/nla.obj-636005630
# 2073    http://nla.gov.au/nla.obj-636091247
# 427     http://nla.gov.au/nla.obj-636091247
# 358     https://nla.gov.au/nla.obj-68375465
# 40      https://nla.gov.au/nla.obj-68375465
# 2065    http://nla.gov.au/nla.obj-724008889
# 434     http://nla.gov.au/nla.obj-724008889
# 2095    http://nla.gov.au/nla.obj-744869630
# 604     http://nla.gov.au/nla.obj-744869630
# 2086    http://nla.gov.au/nla.obj-748141557
# 9       http://nla.gov.au/nla.obj-748141557
# 2078    http://nla.gov.au/nla.obj-752101760
# 380     http://nla.gov.au/nla.obj-752101760
# 2084    http://nla.gov.au/nla.obj-753076802
# 429     http://nla.gov.au/nla.obj-753076802
# 2094    http://nla.gov.au/nla.obj-753479079
# 36      http://nla.gov.au/nla.obj-753479079
# 2077    http://nla.gov.au/nla.obj-754081281
# 2907    http://nla.gov.au/nla.obj-754081281
# 2076    http://nla.gov.au/nla.obj-760289107
# 2961    http://nla.gov.au/nla.obj-760289107
# 2072    http://nla.gov.au/nla.obj-760335335
# 122     http://nla.gov.au/nla.obj-760335335
# 2069    http://nla.gov.au/nla.obj-765536757
# 425     http://nla.gov.au/nla.obj-765536757
# 2082    http://nla.gov.au/nla.obj-768289925
# 1025    http://nla.gov.au/nla.obj-768289925
# 2081    http://nla.gov.au/nla.obj-768329137
# 1026    http://nla.gov.au/nla.obj-768329137
# 2083    http://nla.gov.au/nla.obj-768936943
# 1027    http://nla.gov.au/nla.obj-768936943
# 2085    http://nla.gov.au/nla.obj-788254980
# 2931    http://nla.gov.au/nla.obj-788254980
# 2074   https://nla.gov.au/nla.obj-875780662
# 2615   https://nla.gov.au/nla.obj-875780662
#
#                                     trove_url            trove_id  \
# 1708  https://trove.nla.gov.au/work/236307958  nla.obj-1226109179
# 2641   https://trove.nla.gov.au/work/30060307  nla.obj-1226109179
# 735   https://trove.nla.gov.au/work/205602387  nla.obj-1252107366
# 2045  https://trove.nla.gov.au/work/237613201  nla.obj-1252107366
# 690   https://trove.nla.gov.au/work/200641459  nla.obj-1252263267
# 2534   https://trove.nla.gov.au/work/24167477  nla.obj-1252263267
# 713   https://trove.nla.gov.au/work/203345085  nla.obj-1771610885
# 2988    https://trove.nla.gov.au/work/7113005  nla.obj-1771610885
# 2096  https://trove.nla.gov.au/work/238058947   nla.obj-389050007
# 2741   https://trove.nla.gov.au/work/33565755   nla.obj-389050007
# 2062  https://trove.nla.gov.au/work/237942979   nla.obj-389050376
# 2752   https://trove.nla.gov.au/work/33657268   nla.obj-389050376
# 391   https://trove.nla.gov.au/work/185170546   nla.obj-483060448
# 1218  https://trove.nla.gov.au/work/227406722   nla.obj-483060448
# 271    https://trove.nla.gov.au/work/17504125   nla.obj-485357469
# 1222  https://trove.nla.gov.au/work/227470178   nla.obj-485357469
# 2064  https://trove.nla.gov.au/work/237945398   nla.obj-518308191
# 1581   https://trove.nla.gov.au/work/23458620   nla.obj-518308191
# 2063  https://trove.nla.gov.au/work/237943749   nla.obj-522690001
# 2927    https://trove.nla.gov.au/work/5550156   nla.obj-522690001
# 2070  https://trove.nla.gov.au/work/238004028   nla.obj-597762006
# 2904    https://trove.nla.gov.au/work/5525268   nla.obj-597762006
# 2066  https://trove.nla.gov.au/work/237956276   nla.obj-597769314
# 2905    https://trove.nla.gov.au/work/5525462   nla.obj-597769314
# 2068  https://trove.nla.gov.au/work/237995271   nla.obj-598267619
# 883    https://trove.nla.gov.au/work/21508050   nla.obj-598267619
# 2061  https://trove.nla.gov.au/work/237942681   nla.obj-598579045
# 2948    https://trove.nla.gov.au/work/6193573   nla.obj-598579045
# 2071  https://trove.nla.gov.au/work/238004103   nla.obj-636005630
# 904    https://trove.nla.gov.au/work/21701137   nla.obj-636005630
# 2073  https://trove.nla.gov.au/work/238008662   nla.obj-636091247
# 427    https://trove.nla.gov.au/work/18685300   nla.obj-636091247
# 358   https://trove.nla.gov.au/work/181758222    nla.obj-68375465
# 40     https://trove.nla.gov.au/work/11500235    nla.obj-68375465
# 2065  https://trove.nla.gov.au/work/237946453   nla.obj-724008889
# 434    https://trove.nla.gov.au/work/18731562   nla.obj-724008889
# 2095  https://trove.nla.gov.au/work/238056012   nla.obj-744869630
# 604    https://trove.nla.gov.au/work/19323982   nla.obj-744869630
# 2086  https://trove.nla.gov.au/work/238053149   nla.obj-748141557
# 9      https://trove.nla.gov.au/work/10753694   nla.obj-748141557
# 2078  https://trove.nla.gov.au/work/238034966   nla.obj-752101760
# 380    https://trove.nla.gov.au/work/18429775   nla.obj-752101760
# 2084  https://trove.nla.gov.au/work/238053011   nla.obj-753076802
# 429    https://trove.nla.gov.au/work/18691103   nla.obj-753076802
# 2094  https://trove.nla.gov.au/work/238055834   nla.obj-753479079
# 36     https://trove.nla.gov.au/work/11415630   nla.obj-753479079
# 2077  https://trove.nla.gov.au/work/238033317   nla.obj-754081281
# 2907    https://trove.nla.gov.au/work/5527029   nla.obj-754081281
# 2076  https://trove.nla.gov.au/work/238033248   nla.obj-760289107
# 2961    https://trove.nla.gov.au/work/6399562   nla.obj-760289107
# 2072  https://trove.nla.gov.au/work/238006103   nla.obj-760335335
# 122    https://trove.nla.gov.au/work/13572556   nla.obj-760335335
# 2069  https://trove.nla.gov.au/work/238002346   nla.obj-765536757
# 425    https://trove.nla.gov.au/work/18674223   nla.obj-765536757
# 2082  https://trove.nla.gov.au/work/238042370   nla.obj-768289925
# 1025   https://trove.nla.gov.au/work/22318978   nla.obj-768289925
# 2081  https://trove.nla.gov.au/work/238042365   nla.obj-768329137
# 1026   https://trove.nla.gov.au/work/22319382   nla.obj-768329137
# 2083  https://trove.nla.gov.au/work/238051629   nla.obj-768936943
# 1027   https://trove.nla.gov.au/work/22319620   nla.obj-768936943
# 2085  https://trove.nla.gov.au/work/238053099   nla.obj-788254980
# 2931    https://trove.nla.gov.au/work/5552221   nla.obj-788254980
# 2074  https://trove.nla.gov.au/work/238009872   nla.obj-875780662
# 2615   https://trove.nla.gov.au/work/27592184   nla.obj-875780662
#
#       nla_digitised
# 1708          False
# 2641          False
# 735           False
# 2045          False
# 690           False
# 2534          False
# 713           False
# 2988          False
# 2096          False
# 2741           True
# 2062          False
# 2752           True
# 391           False
# 1218          False
# 271           False
# 1222          False
# 2064          False
# 1581           True
# 2063          False
# 2927           True
# 2070          False
# 2904           True
# 2066          False
# 2905           True
# 2068          False
# 883            True
# 2061          False
# 2948           True
# 2071          False
# 904            True
# 2073          False
# 427            True
# 358           False
# 40             True
# 2065          False
# 434            True
# 2095          False
# 604            True
# 2086          False
# 9              True
# 2078          False
# 380            True
# 2084          False
# 429            True
# 2094          False
# 36             True
# 2077          False
# 2907           True
# 2076          False
# 2961           True
# 2072          False
# 122            True
# 2069          False
# 425            True
# 2082          False
# 1025           True
# 2081          False
# 1026           True
# 2083          False
# 1027           True
# 2085          False
# 2931           True
# 2074          False
# 2615           True

# %%
df.sort_values(by=['trove_id', 'nla_digitised']).drop_duplicates(subset='trove_id', keep='last').shape
# Out:
# (3001, 5)

# %%
# Save as CSV and display a download link
df.to_csv('digital-journals.csv', index=False)
display(FileLink('digital-journals.csv'))
# Out:
# /home/stragu/cloudstor/work/2017-11-30 DSH/2020-10_MUSM7011/trove-python/digital-journals.csv

# %% [markdown]
# ----
#
# Created by [Tim Sherratt](https://timsherratt.org/) for the [GLAM Workbench](https://glam-workbench.github.io/).
#
# Work on this notebook was supported by the [Humanities, Arts and Social Sciences (HASS) Data Enhanced Virtual Lab](https://tinker.edu.au/).
